# %%
from libs.models import MobileNet_V2,ResNet_50,Inception_V3,VGG_19,EfficientNet_V2

# Set the path to your dataset directory
train_data_dir = '/Users/sarath/Documents/Files/aug_image_train'
test_data_dir = '/Users/sarath/Documents/Files/aug_image_test'

print("MobileNet_V2")
MobileNet_V2(train_data_dir, test_data_dir, "ds2")
print("Inception_V3")
Inception_V3(train_data_dir, test_data_dir, "ds2")
print("VGG_19")
VGG_19(train_data_dir, test_data_dir, "ds2")
print("EfficientNet_V2")
EfficientNet_V2(train_data_dir, test_data_dir, "ds2")
print("ResNet_50")
ResNet_50(train_data_dir, test_data_dir, "ds2")
# Out:
# MobileNet_V2
# Found 885 images belonging to 4 classes.
# Found 390 images belonging to 4 classes.
# /Users/sarath/Documents/Files/source files/libs/models.py:158: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False)
# Epoch 1/10
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 26s 651ms/step - accuracy: 0.7002 - loss: 0.7521
# Epoch 2/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 25s 652ms/step - accuracy: 0.9231 - loss: 0.2124
# Epoch 3/10
# ...
